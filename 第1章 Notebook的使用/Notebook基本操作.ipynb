# %% [markdown]
# * 版权及免责声明：
# >1. ©2020 [海南佳达科技有限公司](https://www.jiadakeji.cn)
# >2. 本教程部分文字与图片来源于网络，如有侵犯您的版权，请及时通知我们，我们会尽快获得您的授权或马上删除。
# >3. 本教程原创部分，未经书面授权，**禁止复制、转载和传播**，一经发现，违法必究！

# %% [markdown]
# **由于本套教程使用了Jupyter Notebook为主要编辑器, 因此也引入了一些iPython操作。**
# * 教程特色
#     > 1. 原理与代码结合，讲解深入浅出，帮助学员快速掌握理论知识
#     > 2. 教程和代码一体化，无缝运行实例代码
#     > 3. 原理+小段代码演示（代替理论公式），最终串成完整的案例
#     > 4. 免去准备运行环境和安装配置的障碍
#
# 因此，有必要先给大家讲解一些Notebook项目的基本操作
#
# ***

# %% [markdown]
# <h1>目录<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#执行和调试" data-toc-modified-id="执行和调试-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>执行和调试</a></span></li><li><span><a href="#上传Notebook" data-toc-modified-id="上传Notebook-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>上传Notebook</a></span></li><li><span><a href="#Notebook快捷键" data-toc-modified-id="Notebook快捷键-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Notebook快捷键</a></span></li><li><span><a href="#Notebook中使用Shell命令" data-toc-modified-id="Notebook中使用Shell命令-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Notebook中使用Shell命令</a></span><ul class="toc-item"><li><span><a href="#使用pip来安装自己需要的package-(但不支持apt-get)" data-toc-modified-id="使用pip来安装自己需要的package-(但不支持apt-get)-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>使用pip来安装自己需要的package (但不支持apt-get)</a></span></li><li><span><a href="#查看当前环境中安装的package" data-toc-modified-id="查看当前环境中安装的package-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>查看当前环境中安装的package</a></span></li></ul></li><li><span><a href="#Python代码执行与调试" data-toc-modified-id="Python代码执行与调试-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Python代码执行与调试</a></span></li><li><span><a href="#变量监控" data-toc-modified-id="变量监控-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>变量监控</a></span></li><li><span><a href="#Magic命令" data-toc-modified-id="Magic命令-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Magic命令</a></span><ul class="toc-item"><li><span><a href="#%env：设置环境变量" data-toc-modified-id="%env：设置环境变量-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>%env：设置环境变量</a></span></li><li><span><a href="#%run:-运行python代码" data-toc-modified-id="%run:-运行python代码-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>%run: 运行python代码</a></span></li><li><span><a href="#%%writefile-and-%pycat:-导出cell内容/显示外部脚本的内容" data-toc-modified-id="%%writefile-and-%pycat:-导出cell内容/显示外部脚本的内容-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span><strong>%%writefile and %pycat: 导出cell内容/显示外部脚本的内容</strong></a></span></li></ul></li><li><span><a href="#关于快速查看某个对象/方法/接口的用法" data-toc-modified-id="关于快速查看某个对象/方法/接口的用法-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>关于快速查看某个对象/方法/接口的用法</a></span></li><li><span><a href="#关于调试代码" data-toc-modified-id="关于调试代码-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>关于调试代码</a></span></li></ul></div>

# %% [markdown]
# # 执行和调试
#
# 基于Notebook的方案和传统IDE方案略有不同, Notebook代码块共享变量空间，多个代码块的运行就像IDE中的步进调试运行，请见下图:
# ![](./images/notebook.png)
#
# 插入断点则需要使用Python自带Debugger: PDB.
# 用法请点击这里:
#
# [PDB用法](./Notebook%E8%B0%83%E8%AF%95.ipynb)

# %% [markdown]
# # 上传Notebook
#
# 可以用自己的ipynb文件取代当前默认的Notebook(前提是格式合法)
#
# ![](./images/upload.png)

# %% [markdown]
# # Notebook快捷键
#
#
# 和原生Notebook快捷键基本一致.
#
# 快捷键分成两种状态下的. 一个是命令模式, 一个是编辑模式, 掌握之后事半功倍.
#
# ![](./images/shotcut_command.png)
#
# ![](./images/shotcut_edit.png)
#
#
# ---

# %% [markdown]
# #  Notebook中使用Shell命令
#
# 通过在Shell命令前添加! (感叹号), 就可以执行部分Shell命令. 包括诸如 !pip install这样的命令.
# 不过, !apt-get这种可能引发用户进一步操作的命令是不支持的.
#
# 下面是两个示例.

# %%
#显示当前路径
# !pwd
# Out:
# /srv/data/Python编程基础/第1章 Notebook的使用

# %%
# 查看当前目录
# !ls
# Out:
# images		    Notebook基本操作.ipynb  test.py
# Notebook调试.ipynb  SaveToPythonCode.py

# %% [markdown]
# ## 使用pip来安装自己需要的package (但不支持apt-get)
#
# 例如:

# %%
# !pip install jupyterthemes

# %% [markdown]
# ## 查看当前环境中安装的package

# %%
# !pip list --format=columns

# %%
#以及使用下方命令查看预装软件
# !apt list

# %% [markdown]
# # Python代码执行与调试
#
# Notebook执行Python代码的原理和传统IDE略有不同.
#
# 1. 传统IDE, 当点击Run按钮时, 编译器/解释器开始构建一个进程. 用户通过单步执行/设置断点进行代码调试和变量监控. 当代码出错, 或用户点击Stop按钮时, 进程被杀死, 资源回收.
#
#     而Notebook, 一旦启动, 就是开始创建一个"进程"(kernel). 每一个Cell, 都是一个天然的断点. 当代码出错, 或用户点击Stop按钮时, "进程"通常也不会被杀死.
#
#     因此如果代码陷入死循环等情况, 需要用户手动关闭并重启该"进程".
#
# 2. 此外, Notebook的Cell是可以随意颠倒顺序来执行的. 这点和传统IDE有很大不同.
#
# 3. 作为前端的Notebook, 与后端的进程(kernel), 建立有一个Session. 也就可以同时支持多个Session来控制kernel.

# %% [markdown]
# # 变量监控
#
# 因为Notebook的Cell是可以随意颠倒顺序来执行的, 因此建议安装Notebook的Variable Inspector插件, 方便用户了解当前代码运行状态.
#
# ![](./images/variable_inspector.png)

# %% [markdown]
# ---
#
# # Magic命令
#
# Magic命令是Notebook的高级用法了. 可以运行一些特殊的指令. Magic 命令的前面带有一个或两个百分号（% 或 %%），分别代表行 Magic 命令和单元格 Magic 命令。行 Magic 命令仅应用于编写 Magic 命令时所在的行，而单元格 Magic 命令应用于整个单元格。
#
# 举个例子:

# %%
#显示全部可用的Magic命令
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
#使用Magic命令来统计运行时长
import random

# %%
# %%timeit

prize = 0 
for i in range(100):
    roll = random.randint(1, 6)
    if roll%2 == 0:
        prize += roll
    else:
        prize -= 1
# Out:
# 87.6 µs ± 105 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# ---
#
# **甚至还可以直接嵌入可视化内容, 例如%matplotlib inline:**

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,1,300)
for w in range(2,6,2):
    plt.plot(x, np.sin(np.pi*x)*np.sin(2*w*np.pi*x))

# %% [markdown]
# 这里需要注意的是, 当前技术架构局限, 一个Cell里面只能输出**一张图片**.
# 如果输出多张图片, 可能会有显示异常的问题

# %% [markdown]
# ## %env：设置环境变量
#
# 使用该命令, 可以在不必重启Kernel的情况下管理notebook的环境变量

# %%
# Running %env without any arguments
# lists all environment variables

# The line below sets the environment
# variable OMP_NUM_THREADS
# %env OMP_NUM_THREADS=4
# Out:
# env: OMP_NUM_THREADS=4

# %% [markdown]
# ## %run: 运行python代码
#
# 使用%run 可以运行.py格式的python代码
#
# 当然是用!python也是可以的
#
# 我在项目空间中上传了一个.py文件, 里面只有一行print代码. 我们执行一下看看.
#
# ![](./images/magic_run.png)

# %%
# %run test.py
# Out:
# hello world

# %%
# !python test.py
# Out:
# hello world

# %% [markdown]
# ## **%%writefile and %pycat: 导出cell内容/显示外部脚本的内容**
#
# AI Studio当前支持一定格式文件的预览和处理, 如果您的格式比较特殊, 尚未支持的话, 不妨试试这两个命令.
#
# %%writefile magic可以把cell的内容保存到外部文件里。 而%pycat则可把外部文件展示在Cell中

# %%
# %%writefile SaveToPythonCode.py

from math import sqrt
for i in range(2,10):
    flag=1
    k=int(sqrt(i))
    for j in range(2,k+1):
        if i%j==0:
            flag=0
        break
        if(flag):
            print(i)
    print(k)
# Out:
# Writing SaveToPythonCode.py

# %% [markdown]
# 因为没有指定路径, 所以文件被保存到了当前目录下. 但至少it works.
#
# ![](./images/magic_writefile.png)
#
# 我们再来尝试从中读文件内容

# %%
# %pycat SaveToPythonCode.py

# %% [markdown]
# 更多Magic命令可以点击这里查询
# [Magic命令](https://ipython.readthedocs.io/en/stable/interactive/magics.html)

# %% [markdown]
# # 关于快速查看某个对象/方法/接口的用法
#
# 在要查询的对象前输入?或??并执行即可. 单问号是普通信息, 双问号是详细信息.
#
# 前提: 该对象方法已经被正确导入(import)
#
# 示例:

# %%
import numpy as np

# %%
# ?np.random

# %%
??np.arange

# %% [markdown]
# # 关于调试代码
#
#
# Notebook自带一个调试器, 叫The Python Debugger (pdb)，我们来看看它是如何工作的.

# %%
# 对, 它也是依赖Magic命令启动的.
# 理论上pdb是可以通过脚本形式来启动. 但是在Notebook中不行, 会造成阻断

# %pdb

def func1(a, b):
    return a / b

def func2(x):
    a = x
    b = x - 1
    return func1(a, b)

func2(1)

# %% [markdown]
# 下一节将重点讲一下PDB的用法
#
# [Notebook调试](./Notebook调试.ipynb)
